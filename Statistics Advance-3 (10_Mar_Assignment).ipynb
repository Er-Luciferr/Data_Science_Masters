# %% [markdown]
# <h3>Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
# - Estimation statistics deals with estimating population parameters using sample data.
# - A point estimate is a single value that is used to estimate a population parameter, while an interval estimate provides a range of values within which the population parameter is likely to fall.

# %% [markdown]
# <h3>Q2. Write a Python function to estimate the population mean using a sample mean and standard
# deviation.

# %%
def x(mean):
    mean == x
    return x

# %% [markdown]
# <h3>Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
# - Hypothesis testing is a statistical method used to test a claim or hypothesis about a population parameter using sample data.
# - It is used to make decisions about the population based on the sample data, by determining whether the evidence provided by the sample data supports or contradicts the claim or hypothesis.
# - The importance of hypothesis testing lies in its ability to help us make informed decisions and draw conclusions about the population, based on the sample data. It is widely used in many fields, including medicine, psychology, and economics, to test the effectiveness of treatments, interventions, and policies.

# %% [markdown]
# <h3>Q4. Create a hypothesis that states whether the average weight of male college students is greater than
# the average weight of female college students.

# %% [markdown]
# Null hypothesis (H0): The average weight of male college students is equal to the average weight of female college students.
#
# Alternative hypothesis (Ha): The average weight of male college students is greater than the average weight of female college students.
#
# In this hypothesis, the null hypothesis states that there is no difference in the average weight between male and female college students, while the alternative hypothesis states that the average weight of male college students is greater than that of female college students. To test this hypothesis, we would collect sample data on the weights of male and female college students and use a statistical test to determine whether the evidence supports the null or alternative hypothesis.

# %% [markdown]
# <h3>Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,
# given a sample from each population.

# %%
from scipy.stats import ttest_ind

def test_population_means(sample1, sample2, alpha=0.05):
    t_stat, p_value = ttest_ind(sample1, sample2)
    
    if p_value < alpha:
        result = f'We reject the null hypothesis (p-value={p_value:.3f})'
    else:
        result = f'We fail to reject the null hypothesis (p-value={p_value:.3f})'
    
    return result

# %% [markdown]
# <h3>Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# In hypothesis testing, the null hypothesis (H0) is a statement about a population parameter that is assumed to be true until proven otherwise. The alternative hypothesis (Ha) is a statement that contradicts the null hypothesis and is what we are trying to prove.
#
# Some examples of null and alternative hypotheses are:
#
# - Example 1: Testing the effectiveness of a new drug
#     - Null hypothesis (H0): The new drug is no more effective than the current drug.
#     - Alternative hypothesis (Ha): The new drug is more effective than the current drug.
#
# - Example 2: Testing whether a coin is fair
#     - Null hypothesis (H0): The coin is fair (i.e., the probability of heads is 0.5).
#     - Alternative hypothesis (Ha): The coin is not fair (i.e., the probability of heads is not 0.5).

# %% [markdown]
# <h3>Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
# - 1) Null Hypothesis `(Ho)`
# - 2) Alternate Hypothesis `(Ha)`
# - 3) Statistical Experiment
# - 4) Accept the Null Hypothesis or reject the Null Hypothesis

# %% [markdown]
# <h3>Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
# - **P-value**: The probability of obtaining results as extreme or more extreme than the observed results, assuming that the null hypothesis is true .
# - **Significance in hypothesis testing**: Used to determine the statistical significance of the results and to decide whether to reject or fail to reject the null hypothesis .

# %% [markdown]
# <h3>Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
# parameter set to 10.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import t

x = np.linspace(-5, 5, 1000)
y = t.pdf(x, df=10)

plt.plot(x, y)
plt.title("Student's t-distribution (df=10)")
plt.xlabel('x')
plt.ylabel('Probability density')
plt.show()

# %% [markdown]
# <h3>Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two
# random samples of equal size and a null hypothesis that the population means are equal.

# %%
from scipy import stats

def t_test(sample1, sample2):
    t_statistic, p_value = stats.ttest_ind(sample1, sample2)
    return t_statistic, p_value

# Example usage
sample1 = [1, 2, 3, 4, 5]
sample2 = [6, 7, 8, 9, 10]

t_statistic, p_value = t_test(sample1, sample2)

print(f"t-statistic: {t_statistic}")
print(f"p-value: {p_value}")
# Out:
# t-statistic: -5.0
# p-value: 0.001052825793366539

# %% [markdown]
# <h3>Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
# - **Student's t-distribution**: A type of probability distribution that is similar to the normal distribution, but with heavier tails. It is used for estimating population parameters for small sample sizes or unknown variances .
# - **When to use**: The t-distribution should be used if the population sample size is small (usually less than 30) and the standard deviation is unknown .

# %% [markdown]
# <h3>Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# - **t-statistic**: A value calculated from sample data that is used to determine whether to reject or fail to reject the null hypothesis in a t-test .
# - **Formula**: The formula for a one-sample t-test is `t = (X̄ - μ0) / (s / √n)`, where `X̄` is the sample mean, `μ0` represents the population mean, `s` is the standard deviation of the sample, and `n` stands for the size of the sample .

# %% [markdown]
# <h3>Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be rs500  with a standard deviation of $50.
# <br>Estimate the population mean revenue with a 95% confidence interval.

# %% [markdown]
# population mean: x̄ ± t * (s / √n)
# 500 ± 2.01 * (50 / √50) ≈ (485.7, 514.3)
#
# So, we can estimate with 95% confidence that the population mean revenue for the coffee shop is between $485.7 and  $514.3.

# %% [markdown]
# <h3>Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
# clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
# standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %% [markdown]
# `t = (8 - 10) / (3 / √100) = -6.67`
#
# Since the p-value is less than the significance level of 0.05, we reject the null hypothesis and conclude that there is evidence to suggest that the population mean decrease in blood pressure is not equal to 10 mmHg.

# %% [markdown]
# <h3>Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a
# standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
# is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
# pounds with a significance level of 0.01.

# %% [markdown]
# `z = (4.8 - 5) / (0.5 / √25) = -2`
#
# Since the p-value is greater than the significance level of 0.01, we fail to reject the null hypothesis and conclude that there is not enough evidence to suggest that the population mean weight of the products is less than 5 pounds.

# %% [markdown]
# <h3>Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =
# 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.

# %% [markdown]
# `t = (80 - 75) / √((10^2 / 30) + (8^2 / 40)) ≈ 2.77`
#
# Since the p-value is less than the significance level of 0.01, we reject the null hypothesis and conclude that there is evidence to suggest that the population means for the two groups are not equal.

# %% [markdown]
# <h3>Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV
# program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
# deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %% [markdown]
# `4 ± 2.68 * (1.5 / √50) ≈ (3.43, 4.57)`
#
# So, we can estimate with 99% confidence that the population mean number of ads watched by viewers during a TV program is between 3.43 and 4.57.
